# %% [markdown]
# <a href="https://colab.research.google.com/github/ktm93/tm/blob/master/4week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
# - 용어 정리
# - 딥러닝 강의 클론 코딩
# - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성 하세요.
#
# * 2문장 이상 작성 해 주세요.
# * 주제(단어)와 크게 벗어나지만 않는다면 정답처리 됩니다.
# * 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다. (기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해 주세요.)

# %% [markdown]
# __(예시)__
# ### 심층 신경망
# : 입력층과 출력층 사이에 여러 개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 신층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에서 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# : 매컬론-피츠뉴런을 바탕으로 퍼셉트론 이론 발표(MCP뉴런)
# 간소화된 뇌의 뉴런 개념발표1943년
# 신경세포를 이진 출력을 내는 간단한 논리 회로로 표현
#
# ### 퍼셉트론
# : 프랭크 로젠블렛이 MCP뉴런 모델을 기반으로 퍼셉트론 학습개념 1957년 발표하게 됨
# 자동으로 최적의 가중치를 학습하는 알고리즘, 가중치는 뉴런의 출력 신호를 낼지 말지를 결정하기 위해 입력 특성에 곱하는 계수가 됨.
# 입력-> 계산 -> 출력을 반환
# 활성화 함수 : 뉴런의 출력값을 정함
# 뉴런에서 학습할 때 변하는 것은 가중치, 가중치는 초기화를 통해 무작위된 값을 넣고 학습 과정에서 점차 일정한 값으로 수렴하게 됨
# 학습이 잘 된 다는 것은 좋은 가중치를 얻어 원하는 출력에 점점 가까워지는 값을 얻는 것
# AND연산에는 무리없이 각 진리표에대해 기대 출력과 가까운 값을 출력함
# OR연산도 무리없이 기대출력과 가까운 값을 출력함
# XOR은 2개입력값이 다를때 참을 출력함, 다양한 가중치로 학습을 진행해도 모든 결과값이 0.5근처에 머물며 우리가 원하는 값으로 수렴하지 않음, 해결법은 다층 퍼셉트론을 활용하여 해결함
# 단순 선형 분류기에 불과하다고 연구진들이 말함 -> AI WINTER
# 1986년 다층 퍼셉트론 제시 : 은닉층 활용하게 되면 선형 분류 판별선을 여러개 그리는 효과를 얻음으로써 XOR문제를 해결할 수 있다고 말함 약점은 파라미터 개수가 많아지면서 적절한 가중치와 편향을 학습하는 것이 어렵다는 것 이를 제프리 힌튼이 역전파 알고리즘을 제시하여 문제 해결함 인공지능 연구를 가속화 하는 계기가 됨
#
#
# ### 역전파
# : 뉴런의 가중치를 효율적으로 조정하기 위해 거꾸로 무엇인가를 전파하는 방식
# 연적파에서는 기존의 출력값을 지우고 새로운 출력값으로 전달함
# 은닉층 노드 값과 고정값을 비교하여 값인 큰쪽의 가중치 혹은 편향을 더 크게 조정하여 출력값을 조정함
# 출력값과 지도 데이터 사에 생기는 오차를 이용해 출력층에서 입력층 쪽으로 가중치를 조정하는 것
# 경사하강법을 사용하는것이기도 함
#
# 기울기 소멸 문제 : 알고리즘 학습진행에 잇어 시그모이드와 소프트맥스가 주로 사용된 활성화 함수
# 시그모이드 미분 최대치가 0.3에 불과 여러 층을 거칠수록 기울기는 점차 0에 수렴하는 문제
# 소프트맥스는 출력 값으로 확률 벡터를 얻기위해 사용 됬었는데, 각출력 노드의 출력값을 0에서 1사이로 제한함
# 출력된 값들이 항상 너무 작은값을 가짐
# 신경망이 깊어질수록 오차의 기울기가 점차 작아지며 끝으로 가는도중 기울기가 소실돼버리면서 가중치 조정이 이뤄지지않는 문제 발생
#
# 제프리 힌튼교수
# 다양한 활성화 함수를 제시 , 그중 ReLU라는 활성화 함수를 활용하게 되면 어느정도 문제가 해결됨을 발견함
# 이 활성화 함수는 입력이 음수일 떄는 0출력하지만, 양수일 때는 양수 값을 그대로 출력, 다음 활성함수보다 기울기 소실 문제에 있어 어느정도 면역을 갖게 됨
#
# ### 강화학습
# :에이전트라는 존재가 환경과 상호작용하며, 이 환경에는 보상이라는 기준이 있어서 다양한 시행착오를 겪어가며 보상을 최대화하는 방향으로 학습을 진행
# 다수의 시행착오를 통해 학습이 가능, 비교적 명확한 보상을 설정할 수 있는 문제를 해결하는데 사용되고 있음.
# 2016년 3월 구글 딥마인드의 알파고 이후로 강화 학습 분야가 많은 관심을 받게 되었음
#
# 보상을 최대화 하는 의사 결정 전략 즉 순차적인 행동들을 알아나가는 방법
#
# MDP
# 행동, 상태, 보상함수, 상태변환확률, 감가율 구성요소를 바탕으로 이루어져있음
#
# 에이전트는 의사결정하는 역할
# 환경 : 에이전트의 의사결정을 반영, 에이전트에게 반영된 정보를 주는 역할을 담당
#
# 상태 : 에이전트는 상태라는 것을 기반으로 의사결정을 진행하게 됨. 의사결정을 하기 위해 사용되는 관측값, 행동, 보상을 가공한 정보
#
# 행동 : 에이전트가 의사결정을 통해 취할수 있는 행동 일반적으로 현재 상태에서 취하는 행동을 At라고 표기.
# 이산적 행동 : 에이전트에게 주어지는 행동의 선택지가 있으며 에이전트를 그중 하나 선택
# 연속적 행동 : 선택지마다 특정 값을 수치로 입력, 에이전트는 입력된 값 만큼 행동
#
# 관측 : 환경에서 제공해주는 정보
# 시각적 관측 : 현재 상태의 정보를 이미지로 표현
# 수치적 관측 : 이미지가 아닌 수치로만 표현
#
# 보상함수 : 에이전트가 특정 상태에서 특정 행동을 했을 때 보상을 받게 되고 에이전트는 이 보상정보를 통해 학습을 진행.
#
# 강화학습에서는 에피소드가 끝나게 됐을 때, 에이전트가 지나왔던 상태에서 했던 행동에 대한 정보를 기록하게 됨.그리고 그 정보를 이용하여 그다음 에피소드에 대한 의사결정을 하게 됨. 에피소드가 또 끝나면 이 에피소드를 통해 얻었던 정보로 기록 업데이트 과정 반복
#
# 현재 스텝에서 받았던 보상으로 부터 에피소드가 끝날떄 까지 받았던 보상들을 더한 것을 정보로 이용
#
# 감가율 : 그리스문자 감마, 0~1사이의 값, 1에 가까울수록 미래의 보상에 더 많은 가중치를 두게 됨.
# 반환값 : 현재스텝 부터 받았던 보상부터 에피소드가 끝날 떄까지 받았던 보상들에 감가율을 스텝 차이만큼 곱해서 더해주게됨
#
# 탐험 : 에이전트에게 무작위로 움직이게 설정하여 여러 경로를 시도해 보라는 개념
# 이용 : 에이전트가 찾아놓은 길로 하여 계속해서 선택하고 움직이게 되는 것을 의미
#
# ### 과적합
# :큰차수의 식을 정의하여 더 정학한 식을 위해 차수를 늘리는 방향으로 식을 설계한다면 학습과정에서는 정확히 맞지만, 실전 데이터를 적용했을 때 오차파 발생함
#
# ### 차원의 저주
# : 고정된 크기의 훈련 데이터셋 차원이 늘어남에 따라 특성 공간이 점점 희소해지는 현상
# 차원의 저주 피하기 위해 올바른 변수의 선택, 차원 축소 기법 등을 사용해 주면 됨

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15 부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
#
# * 하나의 코드셀에 해당 코드를 한번에 다 적어서 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# *__주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F0cceeed0-0235-4b0f-af88-0b8c377d5b4b%2F_2020-06-09__9.35.23.png?table=block&id=88fd8912-9356-49a4-9fda-a1a63fe96ea9&width=2870&cache=v2)

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 1
y = 0
w = tf.random.normal([1],0,1)

import math
def sigmoid(x):
  return 1/(1+math.exp(-x))

output = sigmoid(x*w)
print(output)

for i in range(1000):
  output = sigmoid(x*w)
  error = y - output  #실제결과 - 예측결과 
  w = w + x * 0.1 * error  #경사하강법

  if i % 100 == 99:
    print("학습 횟수:",i,"Error:",error,"예측결과:",output)
# Out:
# 0.47477188589261
# 학습 횟수: 99 Error: -0.10010598284299604 예측결과: 0.10010598284299604
# 학습 횟수: 199 Error: -0.05178399422833116 예측결과: 0.05178399422833116
# 학습 횟수: 299 Error: -0.034590451977903586 예측결과: 0.034590451977903586
# 학습 횟수: 399 Error: -0.02588962752851373 예측결과: 0.02588962752851373
# 학습 횟수: 499 Error: -0.020658699939863617 예측결과: 0.020658699939863617
# 학습 횟수: 599 Error: -0.017174253993457355 예측결과: 0.017174253993457355
# 학습 횟수: 699 Error: -0.014689506449480992 예측결과: 0.014689506449480992
# 학습 횟수: 799 Error: -0.012829497265431342 예측결과: 0.012829497265431342
# 학습 횟수: 899 Error: -0.011385568271837804 예측결과: 0.011385568271837804
# 학습 횟수: 999 Error: -0.010232493309882492 예측결과: 0.010232493309882492

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32 부분__)에 나오는 순전파 & 역전파 계산에 대한 문제 입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
#
# (1) 학습률이 0.2 일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2 일 경우 출력층의 노드값 : 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은? : 0.1
